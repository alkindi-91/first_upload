# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Mohammed Al Kindi__
# Specialest

# %% [markdown]
# _I am interested in data science because been able to understand the data and information within will help you understand the customer or person your business reaching too._

# %% [markdown]
# ### The code below will print an output when user enter his name

# %%
name = input("Please enter your name: ")
print("Hello ",name +"!")
# Out:
# Please enter your name: mohammed
# Hello  mohammed!

# %% [markdown]
# - I
# - like
# - coffee
#
# ***
#
# 1- Burger king
# 2- KFC
# 3- Mac
#
# ---
#
# My Favorite search engine is [Google](https://google.com)
